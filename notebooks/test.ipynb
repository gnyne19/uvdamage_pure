# %%
import pandas as pd

file_path = "/cta/users/guneyn23/rpkm/sim_damage_rpkm.bed"

columns = [
    "chrom",
    "start",
    "end",
    "window_id",
    "damage_count",
    "rpkm"
]

df = pd.read_csv(
    file_path,
    sep="\t",
    header=None,
    names=columns,
    nrows=1000
)

df.head()
# Out:
# Running cells with 'plot_env (Python 3.11.15)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n plot_env ipykernel --update-deps --force-reinstall'

# %%
# !head /cta/users/guneyn23/rpkm/sim_damage_rpkm.bed
# Out:
# chr18	24066390	24066440	peak_1_1	2	1.23
# chr18	24066440	24066490	peak_1_2	0	0.00
# chr18	24066490	24066540	peak_1_3	0	0.00
# chr18	24066540	24066590	peak_1_4	0	0.00
# chr18	24066590	24066640	peak_1_5	1	0.61
# chr18	24066640	24066690	peak_1_6	1	0.61
# chr18	24066690	24066740	peak_1_7	0	0.00
# chr18	24066740	24066790	peak_1_8	0	0.00
# chr18	24066790	24066840	peak_1_9	4	2.46
# chr18	24066840	24066890	peak_1_10	1	0.61
